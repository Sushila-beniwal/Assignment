# %% [markdown]
# #ques1
# """
# data encoding:data encoding is technique used to convert one form of data in other form.It helps in security also.
# It is used in data science to convert categorical data into numerical data because most of machine learning algorithms works on numerical data.
# """

# %% [markdown]
# #ques2
# """
# NOminal encoding: It is a techniques used to transform the categorical variable having no intrinsic ordering into numerical variable
# that can we used in machine learning models.One common methode for nominal encoding is one hot encoding which creats a binary vector for each category in the variable.
#
# example: suppose we have a column containing names of cities having unique city three in the dataset then we can use the OHE(one hot encoding) which create binary vector for the all threee unique city.
# like:         delhi---punjab---haryana
#       delhi::   1       0        0
#       punjab::  0       1        0
#       haryana:: 0       0        1
# """

# %% [markdown]
# #ques3
# """
# OHE(one hot encoding)is useful when the unique categories in the features is lower.If we use OHE in case of large unique categories
# it will create sparse matrix.
# """

# %% [markdown]
# #ques4
# """
# i would use OHE because there is 5 unique values present which is not too much high so it will not create sparse matrix.
# """

# %% [markdown]
# #ques5
#
# """
# if two column having categorical value and we apply nominal encoding then new column generated are
# unique_value in categorical col1 + unique_value in categorical col2
# """

# %%
#ques6
"""

"""

# %%
#ques7

import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

# %%
data= pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data['encoded_gender'] = encoder.fit_transform(data['gender'])

# %%
data['Contract'].unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
#only three unque value is there so we can apply OHE

from sklearn.preprocessing import OneHotEncoder

ohe = OneHotEncoder()
ohe.fit_transform(data[['Contract']])
# Out:
# <7043x3 sparse matrix of type '<class 'numpy.float64'>'
# 	with 7043 stored elements in Compressed Sparse Row format>

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...         Yes
# 4                No     Fiber optic             No  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...
